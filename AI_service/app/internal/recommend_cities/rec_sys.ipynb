# %%
# Импорты
import pandas as pd
from lightfm import LightFM
from lightfm.data import Dataset
import optuna
import ast 
from itertools import chain
from lightfm.evaluation import precision_at_k, auc_score, recall_at_k
from lightfm.cross_validation import random_train_test_split
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from scipy.sparse import csr_matrix
import re

# %% [markdown]
# # Подготовка данных

# %%
df = pd.read_excel('data.xlsx').drop('Unnamed: 0', axis=1) # Пользователи
city_f = pd.read_excel('ready_cities.xlsx') # Города
allowed_cities = city_f['city'].unique().tolist()

# Проверка, что все города из списка
def filter_cities(city_string):
    if not isinstance(city_string, str):
        return ''
    cities = [city.strip() for city in city_string.split(', ')]
    filtered = [city for city in cities if city in allowed_cities]
    return ', '.join(filtered)


df['cities_5'] = df['cities_5'].apply(filter_cities)
df['cities_4'] = df['cities_4'].apply(filter_cities)
df['cities_3'] = df['cities_3'].apply(filter_cities)
df['cities_2'] = df['cities_2'].apply(filter_cities)
df['cities_1'] = df['cities_1'].apply(filter_cities)
df['izbrannoe'] = df['izbrannoe'].apply(filter_cities)
df['cities_prosmotr_more_2'] = df['cities_prosmotr_more_2'].apply(filter_cities)
df['cities_prosmotr_less_2'] = df['cities_prosmotr_less_2'].apply(filter_cities)

# %%
# Возраст преобразуем в категорию
def age_group(age_str):
    if age_str.split(' ')[0] == 'Более':
        return 'senior'
    age = int(age_str.split(' - ')[0])  
    if age == 18:
        return 'teen'
    elif age == 21:
        return 'young_adult'
    elif age == 31:
        return 'adult'

# %%
df['age_group'] = df['age_group'].map(age_group)
df['gender'] = df['gender'].astype(str)

# %%
df.head()
# Out:
#     gender age_group                                           cities_5  \
# 0  Женский      teen  санкт-петербург, нижний новгород, екатеринбург...
# 1  Мужской      teen                                             москва
# 2  Женский      teen  санкт-петербург, суздаль, владимир, москва, ту...
# 3  Мужской      teen                         волгоград, краснодар, сочи
# 4  Женский      teen                   санкт-петербург, нижний новгород
#
#          cities_4 cities_3 cities_2                             cities_1  \
# 0  казань, тюмень
# 1
# 2                                                                воронеж
# 3                                                        санкт-петербург
# 4                                    краснодар, рыбинск, углич, кострома
#
#   izbrannoe cities_prosmotr_more_2 cities_prosmotr_less_2  ...  \
# 0                                                          ...
# 1                                                          ...
# 2                                                          ...
# 3                                                          ...
# 4                                                          ...
#
#    morskie_kruizy  plyazhnyj_otdykh  s_detmi  s_kompaniej_15_24  \
# 0           False             False     True               True
# 1           False              True    False               True
# 2           False              True    False               True
# 3           False              True    False               True
# 4           False             False     True               True
#
#    s_kompaniej_25_44  s_kompaniej_45_66  s_semej  v_odinochku  paroj  kuhnya
# 0              False              False    False        False  False     NaN
# 1              False              False     True        False  False     NaN
# 2              False              False     True        False  False     NaN
# 3              False              False    False        False  False     NaN
# 4              False              False    False        False  False     NaN
#
# [5 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 32 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   gender                                 88 non-null     object
#  1   age_group                              88 non-null     object
#  2   cities_5                               88 non-null     object
#  3   cities_4                               88 non-null     object
#  4   cities_3                               88 non-null     object
#  5   cities_2                               88 non-null     object
#  6   cities_1                               88 non-null     object
#  7   izbrannoe                              88 non-null     object
#  8   cities_prosmotr_more_2                 88 non-null     object
#  9   cities_prosmotr_less_2                 88 non-null     object
#  10  poznavatelnyj_kulturno_razvlekatelnyj  88 non-null     bool
#  11  delovoy                                88 non-null     bool
#  12  etnicheskiy                            88 non-null     bool
#  13  religioznyj                            88 non-null     bool
#  14  sportivnyj                             88 non-null     bool
#  15  obrazovatelnyj                         88 non-null     bool
#  16  ekzotic                                88 non-null     bool
#  17  ekologicheskiy                         88 non-null     bool
#  18  selskij                                88 non-null     bool
#  19  lechebno_ozdorovitelnyj                88 non-null     bool
#  20  sobytijnyj                             88 non-null     bool
#  21  gornolyzhnyj                           88 non-null     bool
#  22  morskie_kruizy                         88 non-null     bool
#  23  plyazhnyj_otdykh                       88 non-null     bool
#  24  s_detmi                                88 non-null     bool
#  25  s_kompaniej_15_24                      88 non-null     bool
#  26  s_kompaniej_25_44                      88 non-null     bool
#  27  s_kompaniej_45_66                      88 non-null     bool
#  28  s_semej                                88 non-null     bool
#  29  v_odinochku                            88 non-null     bool
#  30  paroj                                  88 non-null     bool
#  31  kuhnya                                 0 non-null      float64
# dtypes: bool(21), float64(1), object(10)
# memory usage: 9.5+ KB

# %%
# Население и год основания в категорию
def population_group(pop):
    if pop is None:
        return ''
    if pop <= 10000:
        return 'very small'
    if pop <= 50000:
        return 'small'
    elif pop <= 100000:
        return 'medium'
    elif pop <= 500000:
        return 'high medium'
    elif pop <= 1000000:
        return 'high'
    else:
        return 'very high'
def foundation_year(year):
    if year is None:
        return ''
    if year <= 1500:
        return 'very old'
    if year <= 1700:
        return 'medium'
    elif year <= 1900:
        return 'high medium'
    else:
        return 'new'
city_f['population'] = city_f['population'].map(population_group)
city_f['foundation_year'] = city_f['foundation_year'].map(foundation_year)
city_f.head()
# Out:
#             city federal_district     region  fias_level  capital_marker  \
# 0       адыгейск            Южный     Адыгея           4               0
# 1         майкоп            Южный     Адыгея           4               2
# 2  горно-алтайск        Сибирский      Алтай           4               2
# 3         алейск        Сибирский  Алтайский           4               0
# 4        барнаул        Сибирский  Алтайский           4               2
#
#     population foundation_year                                     features
# 0        small             new     семейный отдых, курортный, экологический
# 1  high medium     high medium  семейный отдых, экологический, исторический
# 2       medium     high medium   семейный отдых, исторический, экзотический
# 3        small             new  промышленный, семейный отдых, экологический
# 4         high     high medium     промышленный, экзотический, исторический

# %%
city_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   city              1095 non-null   object
#  1   federal_district  1095 non-null   object
#  2   region            1095 non-null   object
#  3   fias_level        1095 non-null   int64
#  4   capital_marker    1095 non-null   int64
#  5   population        1095 non-null   object
#  6   foundation_year   1095 non-null   object
#  7   features          1095 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 68.6+ KB

# %% [markdown]
# # Подготовка модели

# %% [markdown]
# В модель нужно передать: города, признаки городов, пользователи, признаки пользователей

# %%
dataset = Dataset()
all_users = df.index.astype(str).tolist() # Пользователи
all_items = [i for i in city_f['city'].unique().tolist() if i != ''] # Города
all_user_features = df.columns[4:-1].tolist() 
all_user_features += ['gender'] # Признаки пользователей

# %%
all_city_features = [
    'исторический', 'курортный', 'лыжный', 'промышленный', 'религиозный', 
    'студенческий', 'туристический', 'торговый', 'военный', 'сельскохозяйственный', 
    'медицинский', 'IT и технологический', 'экологический', 'семейный отдых', 
    'экзотический', 'спортивный', 'большой', 'средний', 'маленький'
]
all_city_features.extend(city_f['federal_district'].unique().tolist())
all_city_features.extend(city_f['region'].unique().tolist()) 
all_city_features.extend([f'fias_level: {i}' for i in city_f['fias_level'].unique().tolist()])
all_city_features.extend([f'capital_marker: {i}' for i in city_f['capital_marker'].unique().tolist()])
all_city_features.extend([f'population: {i}' for i in city_f['population'].unique().tolist()])
all_city_features.extend([f'foundation_year: {i}' for i in city_f['foundation_year'].unique().tolist()]) # Признаки городов

# %%
dataset.fit( # Создание датасета
    users=all_users,
    items=all_items,
    user_features=all_user_features,
    item_features=all_city_features
)

# %%
def get_user_features(user_id): # Добавляем учитывания признака пользователей
    row = df.loc[user_id]
    return [feat for feat in all_user_features if row[feat] == True]

user_features = dataset.build_user_features(
    ((str(user_id), get_user_features(user_id)) for user_id in df.index)
)

# %%
(interactions, weights) = dataset.build_interactions( # Добавляем взаимодействия
    chain(((str(user_id), city.strip(), 1) for user_id, cities in df['cities_5'].items() for city in cities.split(',') if city != ''),
    ((str(user_id), city.strip(), 0.8) for user_id, cities in df['cities_4'].items() for city in cities.split(',') if city != ''),
    ((str(user_id), city.strip(), 0.6) for user_id, cities in df['cities_3'].items() for city in cities.split(',') if city != ''),     
    ((str(user_id), city.strip(), 0.4) for user_id, cities in df['cities_2'].items() for city in cities.split(',') if city != ''),     
    ((str(user_id), city.strip(), 0.2) for user_id, cities in df['cities_1'].items() for city in cities.split(',') if city != ''),
    ((str(user_id), city.strip(), 0.9) for user_id, cities in df['izbrannoe'].items() for city in cities.split(',') if city != ''),
    ((str(user_id), city.strip(), 0.8) for user_id, cities in df['cities_prosmotr_more_2'].items() for city in cities.split(',') if city != ''),
    ((str(user_id), city.strip(), 0.4) for user_id, cities in df['cities_prosmotr_less_2'].items() for city in cities.split(',') if city != '')
    )
)

# %%
city_feature_tuples = [] # Учитываем признаки городов
for _, row in city_f.iterrows():
    features = [
        row['federal_district'],
        row['region'],
        f"fias_level: {row['fias_level']}",
        f"capital_marker: {row['capital_marker']}",
        f"population: {row['population']}",
        f"foundation_year: {row['foundation_year']}"
    ]
    city_features = [f.strip() for f in str(row['features']).split(",") if f != 'unknown']
    features.extend(city_features)

    city_feature_tuples.append((row['city'], features))

# %%
item_features = dataset.build_item_features(city_feature_tuples)

# %%
TEST_SIZE = 0.2  
RANDOM_STATE = 42

# %%
train_interactions, test_interactions = random_train_test_split(
    interactions,
    test_percentage=TEST_SIZE,
    random_state=RANDOM_STATE
)

# %%
import optuna # Перебираем гиперпараметры
from lightfm import LightFM
from lightfm.evaluation import precision_at_k, recall_at_k

def objective(trial):
    # Поиск по гиперпараметрам
    no_components = trial.suggest_categorical("no_components", [10, 20, 30, 50, 70, 100])
    loss = trial.suggest_categorical("loss", ["warp", "bpr", "logistic"])
    learning_schedule = trial.suggest_categorical("learning_schedule", ["adagrad", "adadelta"])
    learning_rate = trial.suggest_float("learning_rate", 0.005, 0.1, log=True)
    user_alpha = trial.suggest_float("user_alpha", 1e-6, 1e-4, log=True)
    item_alpha = trial.suggest_float("item_alpha", 1e-6, 1e-4, log=True)
    epochs = trial.suggest_int("epochs", 10, 30)

    # Модель
    model = LightFM(
        no_components=no_components,
        loss=loss,
        learning_schedule=learning_schedule,
        learning_rate=learning_rate,
        user_alpha=user_alpha,
        item_alpha=item_alpha,
        random_state=RANDOM_STATE
    )

    # Обучение
    model.fit(
        train_interactions,
        user_features=user_features,
        item_features=item_features,
        epochs=epochs,
        num_threads=4,
        verbose=False
    )

    # Метрика — Precision@5
    precision = precision_at_k(
        model,
        test_interactions,
        user_features=user_features,
        item_features=item_features,
        k=5
    ).mean()

    return precision

# Запуск Optuna
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)  # можно увеличить до 100–200 для лучших результатов

# Результаты
print("\nЛучшие параметры:")
for key, value in study.best_params.items():
    print(f"{key}: {value}")

print(f"\nЛучший precision@5: {study.best_value:.4f}")
# Out:
# [I 2025-06-22 12:32:12,590] A new study created in memory with name: no-name-cd7371f3-016a-4985-adf7-86870b55f386
# [I 2025-06-22 12:32:15,282] Trial 0 finished with value: 0.05714286118745804 and parameters: {'no_components': 30, 'loss': 'bpr', 'learning_schedule': 'adadelta', 'learning_rate': 0.02179133908866127, 'user_alpha': 1.0300101582875176e-05, 'item_alpha': 9.831986300655612e-05, 'epochs': 23}. Best is trial 0 with value: 0.05714286118745804.
# [I 2025-06-22 12:32:17,376] Trial 1 finished with value: 0.009523809887468815 and parameters: {'no_components': 30, 'loss': 'logistic', 'learning_schedule': 'adadelta', 'learning_rate': 0.012131546359319154, 'user_alpha': 1.0804308042338813e-06, 'item_alpha': 1.318993610000054e-06, 'epochs': 21}. Best is trial 0 with value: 0.05714286118745804.
# [I 2025-06-22 12:32:19,677] Trial 2 finished with value: 0.10952381044626236 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.014874547732213984, 'user_alpha': 1.9254725207117286e-06, 'item_alpha': 1.961960374846073e-05, 'epochs': 22}. Best is trial 2 with value: 0.10952381044626236.
# [I 2025-06-22 12:32:21,178] Trial 3 finished with value: 0.12380951642990112 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.033620251146374035, 'user_alpha': 3.6550740358428887e-06, 'item_alpha': 7.2343171855313636e-06, 'epochs': 25}. Best is trial 3 with value: 0.12380951642990112.
# [I 2025-06-22 12:32:22,480] Trial 4 finished with value: 0.095238097012043 and parameters: {'no_components': 20, 'loss': 'bpr', 'learning_schedule': 'adadelta', 'learning_rate': 0.007650370663297422, 'user_alpha': 5.931671184986642e-05, 'item_alpha': 4.135726868606931e-06, 'epochs': 13}. Best is trial 3 with value: 0.12380951642990112.
# [I 2025-06-22 12:32:24,877] Trial 5 finished with value: 0.009523809887468815 and parameters: {'no_components': 20, 'loss': 'logistic', 'learning_schedule': 'adagrad', 'learning_rate': 0.05650311103768146, 'user_alpha': 8.883743139082629e-06, 'item_alpha': 6.897300532451557e-06, 'epochs': 27}. Best is trial 3 with value: 0.12380951642990112.
# [I 2025-06-22 12:32:27,884] Trial 6 finished with value: 0.12857142090797424 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.014628711600452364, 'user_alpha': 9.902180373716627e-05, 'item_alpha': 2.379388393277573e-05, 'epochs': 29}. Best is trial 6 with value: 0.12857142090797424.
# [I 2025-06-22 12:32:30,597] Trial 7 finished with value: 0.095238097012043 and parameters: {'no_components': 100, 'loss': 'bpr', 'learning_schedule': 'adagrad', 'learning_rate': 0.015122091471874098, 'user_alpha': 1.8110037502070264e-06, 'item_alpha': 1.2879165736268189e-06, 'epochs': 20}. Best is trial 6 with value: 0.12857142090797424.
# [I 2025-06-22 12:32:33,977] Trial 8 finished with value: 0.009523809887468815 and parameters: {'no_components': 70, 'loss': 'logistic', 'learning_schedule': 'adadelta', 'learning_rate': 0.02722844554466247, 'user_alpha': 7.527763638755583e-05, 'item_alpha': 1.467344886146903e-06, 'epochs': 22}. Best is trial 6 with value: 0.12857142090797424.
# [I 2025-06-22 12:32:35,075] Trial 9 finished with value: 0.12857142090797424 and parameters: {'no_components': 20, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.04316080066901652, 'user_alpha': 1.6167456246724193e-06, 'item_alpha': 1.7594065727645918e-06, 'epochs': 20}. Best is trial 6 with value: 0.12857142090797424.
# [I 2025-06-22 12:32:37,576] Trial 10 finished with value: 0.13333334028720856 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.09067961709913819, 'user_alpha': 2.998724139446183e-05, 'item_alpha': 2.9232708032799688e-05, 'epochs': 30}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:32:42,480] Trial 11 finished with value: 0.10952381044626236 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.08504996019751036, 'user_alpha': 3.1741549024166096e-05, 'item_alpha': 2.9380079711572395e-05, 'epochs': 30}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:32:50,777] Trial 12 finished with value: 0.13333332538604736 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.008391534369455634, 'user_alpha': 2.8044101193012995e-05, 'item_alpha': 3.8424204059269065e-05, 'epochs': 30}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:32:54,282] Trial 13 finished with value: 0.12857142090797424 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.005024358083385583, 'user_alpha': 2.5981372590129737e-05, 'item_alpha': 6.974470707517989e-05, 'epochs': 17}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:32:57,474] Trial 14 finished with value: 0.13333332538604736 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.00844517171382474, 'user_alpha': 2.0908537333443528e-05, 'item_alpha': 4.5262003699706646e-05, 'epochs': 27}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:32:59,775] Trial 15 finished with value: 0.12857142090797424 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.09926534126040074, 'user_alpha': 1.2373355518931672e-05, 'item_alpha': 1.4005871841422624e-05, 'epochs': 30}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:00,689] Trial 16 finished with value: 0.12857142090797424 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.06242771512625566, 'user_alpha': 4.563529880696042e-05, 'item_alpha': 4.455099131110964e-05, 'epochs': 10}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:05,887] Trial 17 finished with value: 0.12380951642990112 and parameters: {'no_components': 100, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.005977164675273568, 'user_alpha': 6.034969664443752e-06, 'item_alpha': 4.874899416258685e-05, 'epochs': 26}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:08,875] Trial 18 finished with value: 0.009523809887468815 and parameters: {'no_components': 50, 'loss': 'logistic', 'learning_schedule': 'adagrad', 'learning_rate': 0.021988833749276834, 'user_alpha': 1.7882354343045515e-05, 'item_alpha': 1.2491403705160236e-05, 'epochs': 17}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:12,381] Trial 19 finished with value: 0.095238097012043 and parameters: {'no_components': 50, 'loss': 'bpr', 'learning_schedule': 'adagrad', 'learning_rate': 0.01010618460856052, 'user_alpha': 4.724439707734819e-05, 'item_alpha': 2.9922624706705503e-05, 'epochs': 24}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:14,078] Trial 20 finished with value: 0.12857142090797424 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.03921531642863471, 'user_alpha': 3.246666944538298e-05, 'item_alpha': 4.476514965341046e-06, 'epochs': 28}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:17,677] Trial 21 finished with value: 0.13333332538604736 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.008249660542228074, 'user_alpha': 2.0206475476002916e-05, 'item_alpha': 5.5305815585967265e-05, 'epochs': 27}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:21,180] Trial 22 finished with value: 0.12857142090797424 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.007249082871410901, 'user_alpha': 1.5648711315801098e-05, 'item_alpha': 4.0394037820413095e-05, 'epochs': 28}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:24,576] Trial 23 finished with value: 0.13333332538604736 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.010043904617102488, 'user_alpha': 2.580870024883966e-05, 'item_alpha': 8.036365709579564e-05, 'epochs': 30}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:26,988] Trial 24 finished with value: 0.10476190596818924 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.017814398963199918, 'user_alpha': 4.114759468708087e-05, 'item_alpha': 1.8019706688739497e-05, 'epochs': 25}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:29,779] Trial 25 finished with value: 0.13333332538604736 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.010466973771060362, 'user_alpha': 6.520141909541038e-06, 'item_alpha': 3.323000227698335e-05, 'epochs': 28}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:32,484] Trial 26 finished with value: 0.12380951642990112 and parameters: {'no_components': 30, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.006332155334493516, 'user_alpha': 2.150986039218023e-05, 'item_alpha': 6.43437224953396e-05, 'epochs': 26}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:33,870] Trial 27 finished with value: 0.13333332538604736 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.02819881731438182, 'user_alpha': 1.3191124212204253e-05, 'item_alpha': 2.492686896652195e-05, 'epochs': 17}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:37,573] Trial 28 finished with value: 0.095238097012043 and parameters: {'no_components': 100, 'loss': 'bpr', 'learning_schedule': 'adagrad', 'learning_rate': 0.06463138163724806, 'user_alpha': 6.673246838553405e-05, 'item_alpha': 3.792591922298848e-05, 'epochs': 29}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:38,981] Trial 29 finished with value: 0.009523809887468815 and parameters: {'no_components': 30, 'loss': 'logistic', 'learning_schedule': 'adagrad', 'learning_rate': 0.0050149122878474835, 'user_alpha': 8.98016348224586e-06, 'item_alpha': 8.500867716242627e-05, 'epochs': 24}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:42,378] Trial 30 finished with value: 0.095238097012043 and parameters: {'no_components': 50, 'loss': 'bpr', 'learning_schedule': 'adagrad', 'learning_rate': 0.019453202096112388, 'user_alpha': 3.356755839881596e-05, 'item_alpha': 1.7963165205273805e-05, 'epochs': 27}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:45,776] Trial 31 finished with value: 0.12857142090797424 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.007779714586221876, 'user_alpha': 1.9333919250068673e-05, 'item_alpha': 5.3746306800051276e-05, 'epochs': 27}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:48,987] Trial 32 finished with value: 0.13333332538604736 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.008634290404683519, 'user_alpha': 2.4857856869902814e-05, 'item_alpha': 9.295840298227522e-05, 'epochs': 29}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:52,187] Trial 33 finished with value: 0.13333332538604736 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.012600208374666874, 'user_alpha': 1.5786440488024996e-05, 'item_alpha': 6.146467931318328e-05, 'epochs': 30}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:54,477] Trial 34 finished with value: 0.12857143580913544 and parameters: {'no_components': 30, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.011679660276352729, 'user_alpha': 1.0538612250374007e-05, 'item_alpha': 5.3227986125581655e-05, 'epochs': 26}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:56,889] Trial 35 finished with value: 0.12857142090797424 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.009244923600409715, 'user_alpha': 3.67151462285125e-05, 'item_alpha': 2.151987189500667e-05, 'epochs': 24}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:33:59,286] Trial 36 finished with value: 0.009523809887468815 and parameters: {'no_components': 70, 'loss': 'logistic', 'learning_schedule': 'adagrad', 'learning_rate': 0.006873220666110228, 'user_alpha': 5.3681554095462286e-05, 'item_alpha': 3.676298609119561e-05, 'epochs': 28}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:34:00,382] Trial 37 finished with value: 0.12857143580913544 and parameters: {'no_components': 20, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.013099390571469747, 'user_alpha': 2.46882983012727e-05, 'item_alpha': 8.150498236888021e-06, 'epochs': 22}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:34:03,371] Trial 38 finished with value: 0.12380951642990112 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.008640626172514739, 'user_alpha': 3.920750672637967e-06, 'item_alpha': 1.5084425107080275e-05, 'epochs': 25}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:34:06,088] Trial 39 finished with value: 0.095238097012043 and parameters: {'no_components': 50, 'loss': 'bpr', 'learning_schedule': 'adagrad', 'learning_rate': 0.016103645042616944, 'user_alpha': 9.806702711652323e-05, 'item_alpha': 9.922216994514207e-05, 'epochs': 15}. Best is trial 10 with value: 0.13333334028720856.
# [I 2025-06-22 12:34:11,076] Trial 40 finished with value: 0.13809524476528168 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.02795850275626855, 'user_alpha': 7.257041294606405e-06, 'item_alpha': 1.1040744121256725e-05, 'epochs': 29}. Best is trial 40 with value: 0.13809524476528168.
# [I 2025-06-22 12:34:14,884] Trial 41 finished with value: 0.13333332538604736 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.03179931854846294, 'user_alpha': 5.178312976144492e-06, 'item_alpha': 1.027956036780091e-05, 'epochs': 29}. Best is trial 40 with value: 0.13809524476528168.
# [I 2025-06-22 12:34:18,286] Trial 42 finished with value: 0.12857143580913544 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.02470770427887277, 'user_alpha': 7.801380210945905e-06, 'item_alpha': 5.4795463291616194e-06, 'epochs': 27}. Best is trial 40 with value: 0.13809524476528168.
# [I 2025-06-22 12:34:21,777] Trial 43 finished with value: 0.13333332538604736 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.04698688620004737, 'user_alpha': 2.5722648194941564e-06, 'item_alpha': 2.91839863589979e-06, 'epochs': 30}. Best is trial 40 with value: 0.13809524476528168.
# [I 2025-06-22 12:34:25,487] Trial 44 finished with value: 0.13809524476528168 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.07595439301663653, 'user_alpha': 1.2263409972336262e-05, 'item_alpha': 2.5631161482173488e-05, 'epochs': 29}. Best is trial 40 with value: 0.13809524476528168.
# [I 2025-06-22 12:34:28,875] Trial 45 finished with value: 0.009523809887468815 and parameters: {'no_components': 70, 'loss': 'logistic', 'learning_schedule': 'adadelta', 'learning_rate': 0.07916378393914661, 'user_alpha': 1.1511670366864965e-05, 'item_alpha': 2.4317441579041183e-05, 'epochs': 29}. Best is trial 40 with value: 0.13809524476528168.
# [I 2025-06-22 12:34:31,772] Trial 46 finished with value: 0.12857142090797424 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.07852668039542077, 'user_alpha': 4.112700010670996e-06, 'item_alpha': 1.0623479059706573e-05, 'epochs': 30}. Best is trial 40 with value: 0.13809524476528168.
# [I 2025-06-22 12:34:35,778] Trial 47 finished with value: 0.13333332538604736 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.09747018016409932, 'user_alpha': 1.4430460992800244e-05, 'item_alpha': 2.79897593436093e-05, 'epochs': 28}. Best is trial 40 with value: 0.13809524476528168.
# [I 2025-06-22 12:34:37,377] Trial 48 finished with value: 0.11428570747375488 and parameters: {'no_components': 20, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.048266252539161204, 'user_alpha': 7.13076943167362e-06, 'item_alpha': 1.621025890834277e-05, 'epochs': 29}. Best is trial 40 with value: 0.13809524476528168.
# [I 2025-06-22 12:34:40,086] Trial 49 finished with value: 0.11428572237491608 and parameters: {'no_components': 100, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.06531784284016186, 'user_alpha': 5.0210027951052125e-06, 'item_alpha': 7.74562837579481e-06, 'epochs': 23}. Best is trial 40 with value: 0.13809524476528168.
# [I 2025-06-22 12:34:44,873] Trial 50 finished with value: 0.03333333507180214 and parameters: {'no_components': 70, 'loss': 'bpr', 'learning_schedule': 'adadelta', 'learning_rate': 0.053826088343393474, 'user_alpha': 9.568317341439561e-06, 'item_alpha': 2.135728945221094e-05, 'epochs': 26}. Best is trial 40 with value: 0.13809524476528168.
# [I 2025-06-22 12:34:47,689] Trial 51 finished with value: 0.12857143580913544 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.037777226255063294, 'user_alpha': 1.9850998466532474e-05, 'item_alpha': 4.462918065737565e-05, 'epochs': 27}. Best is trial 40 with value: 0.13809524476528168.
# [I 2025-06-22 12:34:50,281] Trial 52 finished with value: 0.12857142090797424 and parameters: {'no_components': 50, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.005808861949835285, 'user_alpha': 2.9296276385132234e-05, 'item_alpha': 3.100700344804656e-05, 'epochs': 20}. Best is trial 40 with value: 0.13809524476528168.
# [I 2025-06-22 12:34:54,172] Trial 53 finished with value: 0.15714286267757416 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.07532001740060823, 'user_alpha': 1.696934838853893e-05, 'item_alpha': 7.26743364143695e-05, 'epochs': 29}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:02,181] Trial 54 finished with value: 0.15238094329833984 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.08614272540122907, 'user_alpha': 1.63616471631489e-05, 'item_alpha': 1.2441938235820128e-05, 'epochs': 29}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:10,277] Trial 55 finished with value: 0.13809524476528168 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.0722146705900722, 'user_alpha': 1.65795277092487e-05, 'item_alpha': 1.220720825368934e-05, 'epochs': 30}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:13,874] Trial 56 finished with value: 0.1190476194024086 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.07305327745079444, 'user_alpha': 1.7136882058437883e-05, 'item_alpha': 1.2515163065369953e-05, 'epochs': 29}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:17,581] Trial 57 finished with value: 0.009523809887468815 and parameters: {'no_components': 70, 'loss': 'logistic', 'learning_schedule': 'adadelta', 'learning_rate': 0.09446858371127335, 'user_alpha': 1.2872612962353234e-05, 'item_alpha': 6.725303576892022e-06, 'epochs': 28}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:20,785] Trial 58 finished with value: 0.13333332538604736 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.05765114168528711, 'user_alpha': 1.066262698836793e-06, 'item_alpha': 8.447004824369068e-06, 'epochs': 30}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:24,384] Trial 59 finished with value: 0.12857142090797424 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.08706817586074224, 'user_alpha': 7.756740556553375e-06, 'item_alpha': 1.253827792439976e-05, 'epochs': 28}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:27,483] Trial 60 finished with value: 0.12380951642990112 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.07087470429146185, 'user_alpha': 1.0549120767387344e-05, 'item_alpha': 9.29967347358961e-06, 'epochs': 29}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:30,180] Trial 61 finished with value: 0.1428571492433548 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.0836783751416274, 'user_alpha': 1.407546549901766e-05, 'item_alpha': 6.279911742172922e-06, 'epochs': 30}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:31,477] Trial 62 finished with value: 0.12857142090797424 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.08913977960116526, 'user_alpha': 1.515510204617378e-05, 'item_alpha': 3.510738595602069e-06, 'epochs': 10}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:34,887] Trial 63 finished with value: 0.13809524476528168 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.08024106010762104, 'user_alpha': 1.2459421120897831e-05, 'item_alpha': 6.672441695255726e-06, 'epochs': 30}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:37,377] Trial 64 finished with value: 0.13333332538604736 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.07187405641144035, 'user_alpha': 1.1861925325991493e-05, 'item_alpha': 5.446889325677717e-06, 'epochs': 30}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:39,979] Trial 65 finished with value: 0.13809522986412048 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.08051303900623023, 'user_alpha': 8.54388130638417e-06, 'item_alpha': 5.536266750390556e-06, 'epochs': 29}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:42,880] Trial 66 finished with value: 0.12857142090797424 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.058254507127272016, 'user_alpha': 1.3253522708103326e-05, 'item_alpha': 4.283567192066422e-06, 'epochs': 28}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:44,877] Trial 67 finished with value: 0.12857142090797424 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.051867559476456014, 'user_alpha': 2.296130074235129e-05, 'item_alpha': 6.304500740635355e-06, 'epochs': 18}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:47,278] Trial 68 finished with value: 0.12857142090797424 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.06724026538169545, 'user_alpha': 1.7742116601474645e-05, 'item_alpha': 9.554249453378686e-06, 'epochs': 30}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:50,578] Trial 69 finished with value: 0.095238097012043 and parameters: {'no_components': 70, 'loss': 'bpr', 'learning_schedule': 'adagrad', 'learning_rate': 0.06103924382389889, 'user_alpha': 1.0917867065629652e-05, 'item_alpha': 2.316712120804189e-06, 'epochs': 26}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:54,177] Trial 70 finished with value: 0.10952381044626236 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adadelta', 'learning_rate': 0.08050974432255954, 'user_alpha': 5.995603267727387e-06, 'item_alpha': 1.1100185767113852e-05, 'epochs': 29}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:56,684] Trial 71 finished with value: 0.15238095819950104 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.08272620693646207, 'user_alpha': 8.218113664918813e-06, 'item_alpha': 5.3230538652474375e-06, 'epochs': 29}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:35:59,278] Trial 72 finished with value: 0.1190476194024086 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.0871094430600462, 'user_alpha': 9.35060918556835e-06, 'item_alpha': 3.5023944142633023e-06, 'epochs': 30}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:01,577] Trial 73 finished with value: 0.15714284777641296 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.07332345406764731, 'user_alpha': 1.4759334651292262e-05, 'item_alpha': 4.793111500222098e-06, 'epochs': 28}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:06,783] Trial 74 finished with value: 0.15714284777641296 and parameters: {'no_components': 70, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.09923421625451753, 'user_alpha': 1.3989514886124875e-05, 'item_alpha': 6.009463080492756e-06, 'epochs': 27}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:08,777] Trial 75 finished with value: 0.15714284777641296 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.09733014053658443, 'user_alpha': 1.3553157295731958e-05, 'item_alpha': 4.823233591583398e-06, 'epochs': 27}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:09,874] Trial 76 finished with value: 0.009523809887468815 and parameters: {'no_components': 10, 'loss': 'logistic', 'learning_schedule': 'adagrad', 'learning_rate': 0.09601885850048826, 'user_alpha': 1.408531642931991e-05, 'item_alpha': 3.7958306312561847e-06, 'epochs': 28}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:10,675] Trial 77 finished with value: 0.14761903882026672 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.09988457957673916, 'user_alpha': 2.2287064262314303e-05, 'item_alpha': 4.790567198979868e-06, 'epochs': 27}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:11,673] Trial 78 finished with value: 0.13333332538604736 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.09994127304087938, 'user_alpha': 1.866158421629363e-05, 'item_alpha': 4.723043732158027e-06, 'epochs': 25}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:13,276] Trial 79 finished with value: 0.13333332538604736 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.08904834125246314, 'user_alpha': 2.325963767489039e-05, 'item_alpha': 2.77664413529133e-06, 'epochs': 27}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:14,679] Trial 80 finished with value: 0.15714284777641296 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.08644420169973686, 'user_alpha': 2.0457266038687293e-05, 'item_alpha': 1.0447666021733156e-06, 'epochs': 26}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:15,677] Trial 81 finished with value: 0.1428571492433548 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.08539505236868765, 'user_alpha': 2.095278947601989e-05, 'item_alpha': 1.7940838642549084e-06, 'epochs': 26}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:17,278] Trial 82 finished with value: 0.13333332538604736 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.06717237663731948, 'user_alpha': 1.530864246467437e-05, 'item_alpha': 1.153164703605347e-06, 'epochs': 27}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:18,275] Trial 83 finished with value: 0.15714284777641296 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.09114911192756855, 'user_alpha': 2.63011266975777e-05, 'item_alpha': 4.8922893903362894e-06, 'epochs': 25}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:19,278] Trial 84 finished with value: 0.13333332538604736 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.09345648214501084, 'user_alpha': 2.7533998638366112e-05, 'item_alpha': 5.1958536607020714e-06, 'epochs': 25}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:20,077] Trial 85 finished with value: 0.12857142090797424 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.09984951606325784, 'user_alpha': 3.519737196746584e-05, 'item_alpha': 3.045910956454381e-06, 'epochs': 26}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:21,272] Trial 86 finished with value: 0.095238097012043 and parameters: {'no_components': 10, 'loss': 'bpr', 'learning_schedule': 'adagrad', 'learning_rate': 0.07566066745610935, 'user_alpha': 2.1696488162106485e-05, 'item_alpha': 1.6378441003613717e-06, 'epochs': 23}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:21,773] Trial 87 finished with value: 0.13809524476528168 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.09337247817949579, 'user_alpha': 1.8165531565945025e-05, 'item_alpha': 2.2057750182436595e-06, 'epochs': 12}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:23,980] Trial 88 finished with value: 0.12380951642990112 and parameters: {'no_components': 30, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.08984151610654585, 'user_alpha': 2.9302055190979955e-05, 'item_alpha': 3.905237545439848e-06, 'epochs': 24}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:25,274] Trial 89 finished with value: 0.13333332538604736 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.06267410001033079, 'user_alpha': 2.6311317405095624e-05, 'item_alpha': 7.4625998844670535e-06, 'epochs': 26}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:28,486] Trial 90 finished with value: 0.009523809887468815 and parameters: {'no_components': 100, 'loss': 'logistic', 'learning_schedule': 'adagrad', 'learning_rate': 0.08340261501848421, 'user_alpha': 4.193770380651164e-05, 'item_alpha': 4.699005989267268e-06, 'epochs': 28}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:29,672] Trial 91 finished with value: 0.13333332538604736 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.0835328298549828, 'user_alpha': 1.4165585472748759e-05, 'item_alpha': 5.996965481147853e-06, 'epochs': 25}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:30,673] Trial 92 finished with value: 0.13333332538604736 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.07541267595397229, 'user_alpha': 1.6305673111376133e-05, 'item_alpha': 4.823893813894044e-06, 'epochs': 27}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:31,975] Trial 93 finished with value: 0.12857142090797424 and parameters: {'no_components': 20, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.06938579688751047, 'user_alpha': 2.0264431853267584e-05, 'item_alpha': 6.094776996892784e-06, 'epochs': 27}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:33,871] Trial 94 finished with value: 0.15714284777641296 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.09262752089593172, 'user_alpha': 9.991587816604661e-06, 'item_alpha': 4.224069604146506e-06, 'epochs': 28}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:35,173] Trial 95 finished with value: 0.15714284777641296 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.0916142190337769, 'user_alpha': 8.473133708400661e-06, 'item_alpha': 4.1321931912588435e-06, 'epochs': 21}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:36,071] Trial 96 finished with value: 0.15714284777641296 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.09142209908536679, 'user_alpha': 8.641019313285553e-06, 'item_alpha': 3.2330392450222725e-06, 'epochs': 20}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:37,075] Trial 97 finished with value: 0.15714284777641296 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.09121369725698548, 'user_alpha': 8.446593034706508e-06, 'item_alpha': 3.2847704150891128e-06, 'epochs': 21}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:37,873] Trial 98 finished with value: 0.15714284777641296 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.09304508479058815, 'user_alpha': 9.49735685611282e-06, 'item_alpha': 3.143655914743274e-06, 'epochs': 20}. Best is trial 53 with value: 0.15714286267757416.
# [I 2025-06-22 12:36:38,773] Trial 99 finished with value: 0.13333332538604736 and parameters: {'no_components': 10, 'loss': 'warp', 'learning_schedule': 'adagrad', 'learning_rate': 0.07681166319991908, 'user_alpha': 1.1695923024354878e-05, 'item_alpha': 2.1270260378379253e-06, 'epochs': 21}. Best is trial 53 with value: 0.15714286267757416.
# Лучшие параметры:
# no_components: 70
# loss: warp
# learning_schedule: adagrad
# learning_rate: 0.07532001740060823
# user_alpha: 1.696934838853893e-05
# item_alpha: 7.26743364143695e-05
# epochs: 29
#
# Лучший precision@5: 0.1571

# %% [markdown]
# # Обучение

# %%
# Создаём лучшую модель по результатам Optuna
best_model = LightFM(
    no_components=study.best_params['no_components'],
    loss=study.best_params['loss'],
    learning_schedule=study.best_params['learning_schedule'],
    learning_rate=study.best_params['learning_rate'],
    user_alpha=study.best_params['user_alpha'],
    item_alpha=study.best_params['item_alpha'],
    random_state=RANDOM_STATE
)

# Обучение
best_model.fit(
    interactions,
    user_features=user_features,
    item_features=item_features,
    epochs=study.best_params['epochs'],
    num_threads=4,
    verbose=True
)
# Out:
# Epoch: 100%|██████████| 29/29 [00:03<00:00,  8.32it/s]

# %%
def recommend(user_id, model, n=5): # Получаем ТОП-5 рекомендаций
    user_index = list(df.index).index(user_id)
    known_cities = set(df.loc[user_id, 'cities_prosmotr_more_2'].split(', ') + df.loc[user_id, 'cities_prosmotr_less_2'].split(', ') + df.loc[user_id, 'izbrannoe'].split(', ') + df.loc[user_id, 'cities_5'].split(', ') + df.loc[user_id, 'cities_4'].split(', ') + df.loc[user_id, 'cities_3'].split(', ') + df.loc[user_id, 'cities_2'].split(', ') + df.loc[user_id, 'cities_1'].split(', '))
    city_list = list(dataset.mapping()[2].keys())
    
    scores = model.predict(user_ids=user_index,
                           item_ids=np.arange(len(city_list)),
                           user_features=user_features,
                           item_features=item_features)
    
    city_scores = list(zip(city_list, scores))
    city_scores = sorted(city_scores, key=lambda x: -x[1])
    recommendations = [city for city, score in city_scores if city not in known_cities][:n]
    
    return recommendations

# %%
df['recommendations'] = df.index.map(lambda user_id: recommend(user_id, best_model))
recommendations_for_all = {user_id: recommend(user_id, best_model) for user_id in df.index}

# %% [markdown]
# # Результат

# %%
df.head()
# Out:
#     gender age_group                                           cities_5  \
# 0  Женский      teen  санкт-петербург, нижний новгород, екатеринбург...
# 1  Мужской      teen                                             москва
# 2  Женский      teen  санкт-петербург, суздаль, владимир, москва, ту...
# 3  Мужской      teen                         волгоград, краснодар, сочи
# 4  Женский      teen                   санкт-петербург, нижний новгород
#
#          cities_4 cities_3 cities_2                             cities_1  \
# 0  казань, тюмень
# 1
# 2                                                                воронеж
# 3                                                        санкт-петербург
# 4                                    краснодар, рыбинск, углич, кострома
#
#   izbrannoe cities_prosmotr_more_2 cities_prosmotr_less_2  ...  \
# 0                                                          ...
# 1                                                          ...
# 2                                                          ...
# 3                                                          ...
# 4                                                          ...
#
#    plyazhnyj_otdykh  s_detmi  s_kompaniej_15_24  s_kompaniej_25_44  \
# 0             False     True               True              False
# 1              True    False               True              False
# 2              True    False               True              False
# 3              True    False               True              False
# 4             False     True               True              False
#
#    s_kompaniej_45_66  s_semej  v_odinochku  paroj  kuhnya  \
# 0              False    False        False  False     NaN
# 1              False     True        False  False     NaN
# 2              False     True        False  False     NaN
# 3              False    False        False  False     NaN
# 4              False    False        False  False     NaN
#
#                                      recommendations
# 0      [сочи, владимир, анапа, волгоград, челябинск]
# 1  [санкт-петербург, нижний новгород, казань, соч...
# 2  [нижний новгород, казань, сочи, анапа, екатери...
# 3  [москва, нижний новгород, казань, анапа, екате...
# 4            [москва, казань, сочи, анапа, владимир]
#
# [5 rows x 33 columns]
